# %% [markdown]
# <a href="https://colab.research.google.com/github/CarolCB-2004/Primer-Parcial/blob/main/DataScience.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%timeit
L = []
for n in range(1000):
  L.append(n ** 2)
# Out:
# 85.5 µs ± 16.1 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
